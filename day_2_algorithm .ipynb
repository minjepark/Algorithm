# %% [markdown]
# ### 1번. 아래 예제와 같이 고양이를 출력하시오.
# 오늘의 문풀!
#
# 1)백슬러쉬 하나만 있으면 출력이 되지 않고, 앞단을 띄어쓰기 하지않는다.
#
# 2)'''을 쓰고 칸을 내리면 첫째줄이 빈칸이 된다.
#
# 3)백슬라이스 두개를 쓰고 싶으면 4개를 입력해야한다.
#
# 4)map(float, input().split()) 는 안에 2개의 요소를 넣어야 한다. 2번째를 1번째 형식으로 모두 변환한다는 의미이다.
#
# 5)나누기에서 몫을 반환하기 위해서는 //, 나머지를 반환하려면 %, 진짜 나누기를 하려면 /을 사용한다.
#
#  ![image.png](attachment:image.png)

# %%
cat = """\    /\
 )  ( ')
(  /  )
 \(__)|
"""
print(cat)
# Out:
# \    / )  ( ')
# (  /  )
#  \(__)|

# %% [markdown]
# ###  2번.아래 예제와 같이 개를 출력하시오.
# ![image.png](attachment:image.png)

# %%
dog = '''|\_/|
|q p|   /}
( 0 )"""\\
|"^"`    |
||_/=\\\\__|
'''

print(dog)
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|

# %% [markdown]
# ### 문제 3
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = int(input())
c = a + b
print(c)
# Out:
# 1
# 2
# 3

# %%
a,b = map(float, input().split()) #변수가 없다면 map는 어디에 있다. 이렇게 나오고 변수를 지정해주면 그 변수가 수정이 됩니다. 
print(a + b)
# Out:
# 1 2
# 3.0

# %%
a,b = map(int, input().split())
# Out:
# 1 2
# 0

# %% [markdown]
# ### 문제 4
# ![image.png](attachment:image.png)

# %%
a, b = map(int, input().split())
print(a-b)
# Out:
# 3 2
# 1

# %% [markdown]
# ### 문제 5
# ![image.png](attachment:image.png)

# %%
a, b = map(int, input().split())
print(a*b)
# Out:
# 1 2
# 2

# %% [markdown]
# ### 문제 6
# ![image.png](attachment:image.png)

# %%
a,b = map(int, input().split())
print(a/b)
# Out:
# 4 5
# 0.8

# %% [markdown]
# ### 문제 7
# ![image.png](attachment:image.png)

# %%
a, b = map(int, input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
# Out:
# 7 3
# 10
# 4
# 21
# 2
# 1

# %% [markdown]
# ### 문제 8
# ![image.png](attachment:image.png)

# %%
a,b,c = map(int, input().split())
print((a+b)%c)
print(((a%c)+(b%c))%c)
print((a*b)%c)
print(((a%c)*(b%c))%c)
# Out:
# 5 8 4
# 1
# 1
# 0
# 0

# %% [markdown]
# ### day2의 문풀!!!
# 1) 숫자를 더하라! >> 형변환을 통해 int > str > 그 다음 끝자리에 '0'을 필요한만큼 붙이고, 다시 int로 변환시킨다.
#
# 2) 윤년이란.. 4의 배수이면서 400의 배수이지만 100의 배수는 아닌 해를 윤년이라고 한다.
#
# 3) 아니다! 는 a != b 이렇게 표시한다! 느낌표 먼저!!
#
# 4)if와 elif: if만 있는 식은 각각의 if를 모두 확인하고 가지만, if와 elif가 있는 알고리즘은 if가 맞다면 eiif는 넘어간다.
#
# 5) 논리연산자 and,

# %% [markdown]
# ### 문제 9
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = (input())
c = (a*int(b[-1]))
d = (a*int(b[-2]))
f = (a*int(b[-3]))
print(c)
print(d)
print(f)
print(c + int(str(d)+'0')+int(str(f)+'00'))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720

# %% [markdown]
# ## 2단계
# ### 문제 1
# ![image.png](attachment:image.png)

# %%
a,b = map(int, input().split())

if a > b:
    print('>')
elif a < b:
    print('<')
else:
    print('==')
# Out:
# 10 10
# ==

# %% [markdown]
# ### 문제 2
# ![image.png](attachment:image.png)

# %%
score = int(input())

if score >= 90:
    print('A')
elif score >= 80:
    print('B')
elif score >= 70:
    print('C')
elif score >= 60:
    print('D')
else: 
    print('F')
# Out:
# 90
# A

# %% [markdown]
# ### 문제 3
# #### 윤년문제
# ![image.png](attachment:image.png)

# %%
a = int(input())

if a % 4 == 0 and (a % 100 != 0 or a % 400 ==0) :
    print(1)
else:
    print(0)
# Out:
# 2000
# 1

# %% [markdown]
# ### 문제 4
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = int(input())

if a>0 and b>0:
    print(1)
elif a>0 and b<0:
    print(4)
elif a<0 and b>0:
    print(2)
else:
    print(3)
# Out:
# -4
# -2
# 3

# %% [markdown]
# ### 문제 5
# ![image.png](attachment:image.png)

# %%
hour, minute = map(int, input().split())
